# %%
#import libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#import Data
file= 'exportmenporregion.csv'
datos=pd.read_csv(file,
                       header=0,
                       sep=',',
                       parse_dates=False,
                       skip_blank_lines=True,
                 encoding='latin-1')
datos
# Out:
#         Pais_comprador           Regiones  2006/Enero  2006/Febrero  \
# 0       América Latina          Altos Sur      559818        887991
# 1       América Latina             Centro    12566736       8912795
# 2       América Latina             Valles           0             0
# 3       América Latina                Sur     1132854        905186
# 4       América Latina    Sierra de Amula           0             0
# 5       América Latina  Sierra Occidental           0             0
# 6       América Latina            Ciénega     5400194       8711949
# 7       América Latina          Costa Sur           0             0
# 8       América Latina              Norte           0             0
# 9       América Latina        Costa Norte      248989        259453
# 10      América Latina            Sureste           0             0
# 11      América Latina        Altos Norte      718777        668903
# 12      América Latina                ZMG    35921527      36931420
# ...

# %%
#limpiar base de datos
datos2=datos.iloc[:,2:141]
datos3=datos.iloc[:,0:2]
datos2=datos2.astype(float)
datosc=datos3.join(datos2)

index= datosc.index.isin([14,29,44,59,74,89])
datosgroupbycountry=datosc[index]
datosc=datosc[~index]

datosc
# Out:
#         Pais_comprador           Regiones   2006/Enero  2006/Febrero  \
# 0       América Latina          Altos Sur     559818.0      887991.0
# 1       América Latina             Centro   12566736.0     8912795.0
# 2       América Latina             Valles          0.0           0.0
# 3       América Latina                Sur    1132854.0      905186.0
# 4       América Latina    Sierra de Amula          0.0           0.0
# 5       América Latina  Sierra Occidental          0.0           0.0
# 6       América Latina            Ciénega    5400194.0     8711949.0
# 7       América Latina          Costa Sur          0.0           0.0
# 8       América Latina              Norte          0.0           0.0
# 9       América Latina        Costa Norte     248989.0      259453.0
# 10      América Latina            Sureste          0.0           0.0
# 11      América Latina        Altos Norte     718777.0      668903.0
# 12      América Latina                ZMG   35921527.0    36931420.0
# ...

# %%
#convertir a CSV
datosc.to_csv('DataframeExportmenporregion.csv')
